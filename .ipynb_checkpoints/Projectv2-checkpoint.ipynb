# %% [markdown]
# # Estimación de Masas Nucleares Mediante Redes Neuronales Probabilísticas

# %%
# Librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mdn
import matplotlib.ticker as ticker

# %% [markdown]
# # Datos de AME(2020) y NNDC

# %%
# Base de datos AME 2020
mass = pd.read_csv("NUBASE1.csv")
mass.columns = ['AAA','ZZZi','AEl', 's', 'Mass', 'dMass']
mass['Mass'] = mass['Mass'].str.replace('#', '.0')
mass['dMass'] = mass['dMass'].str.replace('#', '.0')
mass['ZZZi'] = mass['ZZZi'].astype(str).str[:-1].astype(np.int64)
mass['AAA'] = mass['AAA']
mass = mass.sort_values('ZZZi')
mass = mass.reset_index()
mass = mass.drop('index',axis = 1)
mass = mass.drop('s', axis = 1)
mass
# Out:
#       AAA  ZZZi    AEl          Mass   dMass
# 0       1     1     1H   7288.971064   1E-05
# 1       2     1     2H  13135.722895   1E-05
# 2       3     1     3H    14949.8109   8E-05
# 3       7     1     7H       49140.0  1000.0
# 4       4     1     4H         24620     100
# ...   ...   ...    ...           ...     ...
# 5837  293   117  293Ts      194430.0   780.0
# 5838  294   117  294Ts      196400.0   590.0
# 5839  294   118  294Og      199320.0   550.0
# 5840  293   118  293Og      198800.0   710.0
# 5841  295   118  295Og      201370.0   660.0
#
# [5842 rows x 5 columns]

# %%
# Energía de primer estado excitado de NNDC
first_ex = pd.read_csv("1st_ExcitedStateEnergy.csv")
first_ex.z = first_ex.z
first_ex.n = first_ex.n
first_ex.columns = ['n','z','First']
first_ex = first_ex.sort_values('z')
first_ex
# Out:
#         n    z    First
# 0       3    1    310.0
# 1       4    1   3100.0
# 2       5    1   4100.0
# 3       6    1  15000.0
# 4       2    2  20210.0
# ...   ...  ...      ...
# 2187  158  108     85.0
# 2188  159  108     57.0
# 2190  163  110    283.0
# 2189  160  110   1130.0
# 2191  171  113    105.0
#
# [2192 rows x 3 columns]

# %%
# Se crea una nueva característica energía del primer estado excitado
mass['FirstExc'] = np.nan

# Se asignan los valores de la energía del primer estado excitado a los correspondientes Z y N

for i in range(len(np.array(first_ex.index))):
    
    A = first_ex.at[i,'z'] + first_ex.at[i,'n']
    FE = first_ex.at[i,'First']
    
    for j in range(len(np.array(mass.index))):
        
        if (first_ex.at[i,'z'] == mass.at[j, 'ZZZi']):
                        
            if (float(A) == float(mass.at[j, 'AAA'])):
                mass.at[j, 'FirstExc'] = FE
                break

        if first_ex.at[i,'z'] < mass.at[j, 'ZZZi']:
            break

# %%
# Se incluye el número de neutrones
mass['NNNi'] = mass['AAA']-mass['ZZZi']

# %%
# Se incluye los nucleones por fuera o faltantes de las capas N,Z = 2,8,20,18,50,82,126
mass['DeltaZ']=np.nan
mass['DeltaN']=np.nan

for i in range(len(np.array(mass.index))):
    
    Z = mass.at[i,'ZZZi']
    
    # Se llena la característica DeltaZ
    if (0 <= Z < 2):
        mass.at[i,'DeltaZ'] = min(abs(Z-0),abs(Z-2))
        
    if (2 <= Z < 8):
        mass.at[i,'DeltaZ'] = min(abs(Z-2),abs(Z-8))  

    if (8 <= Z < 20):
        mass.at[i,'DeltaZ'] = min(abs(Z-8),abs(Z-20))            

    if (20 <= Z < 28):
        mass.at[i,'DeltaZ'] = min(abs(Z-20),abs(Z-28))            

    if (28 <= Z < 50):
        mass.at[i,'DeltaZ'] = min(abs(Z-28),abs(Z-50))            

    if (50 <= Z < 82):
        mass.at[i,'DeltaZ'] = min(abs(Z-50),abs(Z-82))            

    if (82 <= Z < 126):
        mass.at[i,'DeltaZ'] = min(abs(Z-82),abs(Z-126))            
        
    if (126 <= Z ):
        mass.at[i,'DeltaZ'] = abs(Z-126)  
        
        
    N = mass.at[i,'NNNi']
        
    # Se llena la característica DeltaN
    if (0 <= N < 2):
        mass.at[i,'DeltaN'] = min(abs(N-0),abs(N-2)) 
        
    if (2 <= N < 8):
        mass.at[i,'DeltaN'] = min(abs(N-2),abs(N-8))

    if (8 <= N < 20):
        mass.at[i,'DeltaN'] = min(abs(N-8),abs(N-20))            

    if (20 <= N < 28):
        mass.at[i,'DeltaN'] = min(abs(N-20),abs(N-28))            

    if (28 <= N < 50):
        mass.at[i,'DeltaN'] = min(abs(N-28),abs(N-50))            

    if (50 <= N < 82):
        mass.at[i,'DeltaN'] = min(abs(N-50),abs(N-82))            

    if (82 <= N < 126):
        mass.at[i,'DeltaN'] = min(abs(N-82),abs(N-126))            
        
    if (126 <= N ):
        mass.at[i,'DeltaN'] = abs(N-126)

# %%
# Se incluye la suma de los nucleones totales por fuera o faltantes en una capa cerrada
mass['DeltaSum'] = mass['DeltaZ'] + mass['DeltaN']

# %%
# Se añaden las demás características del modelo de gota líquida
mass['A^2/3']  = mass['AAA']**(2/3)
mass['Z(Z-1)/A^1/3']  = mass['ZZZi']*(mass['ZZZi']-1.0)/mass['AAA']**(1/3)
mass['(N-Z)^2/A']  = (mass['NNNi'] - mass['ZZZi'])**2/mass['AAA']
mass['ZEO'] = np.nan
mass['NEO'] = np.nan

for i in range(len(np.array(mass.index))):

    if (mass.at[i,'ZZZi']%2 == 0):
        mass.at[i,'ZEO']  = 0 
    else:
        mass.at[i,'ZEO']  = 1
        
    if (mass.at[i,'NNNi']%2 == 0):
        mass.at[i,'NEO']  = 0 
    else:
        mass.at[i,'NEO']  = 1

# %%
# Se guardan los datos del dataframe con 12 características a implementar
mass = mass.dropna(subset=['Mass'])
mass.reset_index()
mass.to_csv('FULLCHAR.csv', index = False)

# %%
massF = pd.read_csv("FULLCHAR.csv")
massF
# Out:
#       AAA  ZZZi    AEl           Mass       dMass  FirstExc  NNNi  DeltaZ  \
# 0       1     1     1H    7288.971064     0.00001       NaN     0     1.0
# 1       2     1     2H   13135.722895     0.00001       NaN     1     1.0
# 2       3     1     3H   14949.810900     0.00008       NaN     2     1.0
# 3       7     1     7H   49140.000000  1000.00000   15000.0     6     1.0
# 4       4     1     4H   24620.000000   100.00000     310.0     3     1.0
# ...   ...   ...    ...            ...         ...       ...   ...     ...
# 5821  293   117  293Ts  194430.000000   780.00000       NaN   176     9.0
# 5822  294   117  294Ts  196400.000000   590.00000       NaN   177     9.0
# 5823  294   118  294Og  199320.000000   550.00000       NaN   176     8.0
# 5824  293   118  293Og  198800.000000   710.00000       NaN   175     8.0
# 5825  295   118  295Og  201370.000000   660.00000       NaN   177     8.0
#
#       DeltaN  DeltaSum      A^2/3  Z(Z-1)/A^1/3  (N-Z)^2/A  ZEO  NEO
# 0        0.0       1.0   1.000000      0.000000   1.000000  1.0  0.0
# 1        1.0       2.0   1.587401      0.000000   0.000000  1.0  1.0
# 2        0.0       1.0   2.080084      0.000000   0.333333  1.0  0.0
# 3        2.0       3.0   3.659306      0.000000   3.571429  1.0  0.0
# 4        1.0       2.0   2.519842      0.000000   1.000000  1.0  1.0
# ...      ...       ...        ...           ...        ...  ...  ...
# 5821    50.0      59.0  44.114201   2043.405906  11.880546  1.0  0.0
# 5822    51.0      60.0  44.214517   2041.086487  12.244898  1.0  1.0
# 5823    50.0      58.0  44.214517   2076.277633  11.442177  0.0  0.0
# 5824    49.0      57.0  44.114201   2078.637042  11.088737  0.0  1.0
# 5825    51.0      59.0  44.314720   2073.928901  11.800000  0.0  1.0
#
# [5826 rows x 15 columns]

# %%
# Gráficas de N,Z vs deficit de mass
# %matplotlib inline
fig = plt.figure(figsize = (8,8))
x = massF['NNNi'].to_numpy()
y = massF['ZZZi'].to_numpy()
cmass = massF['Mass'].to_numpy()
plt.scatter(x,y, c = cmass)
plt.xlabel('N', fontsize= 20)
plt.ylabel('Z', fontsize= 20)


def fmt(x, pos):
    a, b = '{:.2e}'.format(x).split('e')
    b = int(b)
    return r'${} \times 10^{{{}}}$'.format(a, b)

plt.colorbar(format=ticker.FuncFormatter(fmt))

plt.show()

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plot = plt.figure(figsize=(10,10)).gca(projection='3d')
plot.scatter(np.array(massF['NNNi']), np.array(massF['ZZZi']), np.array(massF['Mass']), s = 10)
plot.set_xlabel('N', fontsize= 20, labelpad=10)
plot.set_ylabel('Z', fontsize= 20, labelpad=10)
plot.set_zlabel('Mass Excess [keV]', fontsize= 20, labelpad=20)
plt.show()

# %%
first_excopy = first_ex[first_ex.First != first_ex['First'].max()]
first_excopy = first_excopy[first_excopy.First != first_excopy['First'].max()]
first_excopy = first_excopy[first_excopy.First != first_excopy['First'].max()]

nn = first_excopy['n'].to_numpy()
zz = first_excopy['z'].to_numpy()
first = np.sqrt(first_excopy['First'].to_numpy())

fig = plt.figure(figsize = (8,8))
plt.scatter(nn,zz, c = first, s = 10)
plt.xlabel('N', fontsize= 20)
plt.ylabel('Z', fontsize= 20)
plt.colorbar()

plt.show()


# SE GRAFICA LA RAÍZ CUADRADA DE LA ENERGÍA DEL PRIMER ESTADO EXCITADO Y SE ELIMINAN (SOLO PARA LA GRÁFICA) 
# LOS TRES VALORES MAYORES CON EL PROPÓSITO DE MOSTRAR MÁS CLARAMENTE LA INFORMACIÓN DE LA ESTRUCTURA QUE ESTA 
#CARACTERÍSTICA POSEE

# %%
DN = massF['DeltaN'].to_numpy()
DZ = massF['DeltaZ'].to_numpy()
DS = massF['DeltaSum'].to_numpy()

fig = plt.figure(figsize = (8,8))
plt.scatter(x,y, c = DN)
plt.xlabel('N', fontsize= 20)
plt.ylabel('Z', fontsize= 20)
plt.colorbar()
plt.show()

fig = plt.figure(figsize = (8,8))
plt.scatter(x,y, c = DZ)
plt.xlabel('N', fontsize= 20)
plt.ylabel('Z', fontsize= 20)
plt.colorbar()
plt.show()


fig = plt.figure(figsize = (8,8))
plt.scatter(x,y, c = DS)
plt.xlabel('N', fontsize= 20)
plt.ylabel('Z', fontsize= 20)
plt.colorbar()
plt.show()

# %% [markdown]
# # Datos de entrenamiento

# %% [markdown]
# #### M12
# Datos de déficit de masas con 12 características

# %%
# Datos M12: Ajuste de déficit de masas con 12 características

massF12 = massF
massF12 = massF12.dropna(subset=['FirstExc'])
massF12 = massF12.dropna(subset=['Mass'])

# Arreglo con los datos. Características por filas y datos por columnas
X12 = massF12[['AAA','ZZZi', 'NNNi', 'A^2/3', 'Z(Z-1)/A^1/3', '(N-Z)^2/A', 'ZEO', 'NEO', 'FirstExc', 'DeltaZ', 'DeltaN', 'DeltaSum']].to_numpy()

# Se normalizan los datos
#X12 = X12.transpose()
#for i in range(X12.shape[0]):
#    X12[i] = (X12[i]-min(X12[i]))/(max(X12[i])-min(X12[i]))
#X12 = X12.transpose()

print('\nDatos de entrenamiento normalizados 12 características:\n\n')
print('X =',X12, '\n\n Dimensiones:', X12.shape)

# Masas
Y12 = massF12['Mass'].to_numpy()
#Y12 = (Y12-min(Y12))/(max(Y12)-min(Y12))
Y12 = Y12.reshape(2191,-1)
print('\n\nY =',Y12, '\n\n Dimensiones:', Y12.shape)
# Out:
# Datos de entrenamiento normalizados 12 características:
#
#
# X = [[  7.   1.   6. ...   1.   2.   3.]
#  [  4.   1.   3. ...   1.   1.   2.]
#  [  5.   1.   4. ...   1.   2.   3.]
#  ...
#  [270. 110. 160. ...  16.  34.  50.]
#  [273. 110. 163. ...  16.  37.  53.]
#  [284. 113. 171. ...  13.  45.  58.]]
#
#  Dimensiones: (2191, 12)
#
#
# Y = [[ 49140.]
#  [ 24620.]
#  [ 32890.]
#  ...
#  [134680.]
#  [138490.]
#  [166590.]]
#
#  Dimensiones: (2191, 1)

# %% [markdown]
# #### M11
# Datos de déficit de masas con 11 características. Eliminando la energía del primer estado excitado

# %%
# Datos M11: Ajuste de déficit de masas con 12 características

massF11=massF
massF11 = massF11.drop(columns=['FirstExc'])
massF11 = massF11.dropna(subset=['Mass'])

# Arreglo con los datos. Características por filas y datos por columnas
X11 = massF11[['AAA','ZZZi', 'NNNi', 'A^2/3', 'Z(Z-1)/A^1/3', '(N-Z)^2/A', 'ZEO', 'NEO', 'DeltaZ', 'DeltaN', 'DeltaSum']].to_numpy()

# Se normalizan los datos
#X11 = X11.transpose()
#for i in range(X11.shape[0]):
#    X11[i] = (X11[i]-min(X11[i]))/(max(X11[i])-min(X11[i]))
#X11 = X11.transpose()

print('\nDatos de entrenamiento normalizados 11 características:\n\n')
print('X =',X11, '\n\n Dimensiones:', X11.shape)

# Masas
Y11 = massF11['Mass'].to_numpy()
#Y11 = (Y11-min(Y11))/(max(Y11)-min(Y11))
Y11 = Y11.reshape(5826,-1)
print('\n\nY =',Y11, '\n\n Dimensiones:', Y11.shape)
# Out:
# Datos de entrenamiento normalizados 11 características:
#
#
# X = [[  1.   1.   0. ...   1.   0.   1.]
#  [  2.   1.   1. ...   1.   1.   2.]
#  [  3.   1.   2. ...   1.   0.   1.]
#  ...
#  [294. 118. 176. ...   8.  50.  58.]
#  [293. 118. 175. ...   8.  49.  57.]
#  [295. 118. 177. ...   8.  51.  59.]]
#
#  Dimensiones: (5826, 11)
#
#
# Y = [[  7288.971064]
#  [ 13135.722895]
#  [ 14949.8109  ]
#  ...
#  [199320.      ]
#  [198800.      ]
#  [201370.      ]]
#
#  Dimensiones: (5826, 1)

# %% [markdown]
# # Datos de test FRDM(2012)
#
# # faltaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa

# %%
# Datos de test
test = pd.read_csv('FRDM2012.csv')
test.columns = ['Z','N','A','MthFL']
test
# Out:
#         Z    N    A   MthFL
# 0       8    8   16   -5.15
# 1       8    9   17   -1.49
# 2       8   10   18   -2.81
# 3       8   11   19    2.15
# 4       8   12   20    2.19
# ...   ...  ...  ...     ...
# 9313  135  201  336  349.30
# 9314  135  202  337  349.90
# 9315  135  203  338  351.39
# 9316  135  204  339  352.48
# 9317  136  203  339  358.58
#
# [9318 rows x 4 columns]

# %% [markdown]
# # Modelo de Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()
Y12 = Y12.reshape(2191,)
model.fit(X12,Y12)
# Out:
# RandomForestRegressor()

# %%
PRED = model.predict(X12)
PRED
# Out:
# array([ 46636.586 ,  26174.14  ,  33469.8575, ..., 132474.    ,
#        135287.6   , 151222.7   ])

# %%
fig = plt.figure(figsize = (8,8))

plt.scatter(massF12['NNNi'].to_numpy(),massF12['ZZZi'].to_numpy(), c = PRED-massF12['Mass'].to_numpy(), s = 10)

plt.xlabel('N', fontsize= 20)
plt.ylabel('Z', fontsize= 20)
plt.colorbar()
plt.show()

# %% [markdown]
# # Modelo de Mixture Density Network (MDN)

# %%
import tensorflow as tf
from tensorflow import keras
import mdn

# %%
# Modelo de mixture density network
N_HIDDEN = 6  # number of hidden units in the Dense layer
N_MIXES = 1  # number of mixture components
OUTPUT_DIMS = 12  # number of real-values predicted by each mixture component

model = keras.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, batch_input_shape=(None, 1), activation='relu'))
model.add(mdn.MDN(OUTPUT_DIMS, N_MIXES))
model.compile(loss=mdn.get_mixture_loss_func(OUTPUT_DIMS,N_MIXES), optimizer=keras.optimizers.Adam( learning_rate=0.001))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 6)                 12
#
#  mdn_1 (MDN)                 (None, 25)                175
#
# =================================================================
# Total params: 187
# Trainable params: 187
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=Y12, y=X12, batch_size=128, epochs=300, validation_split=0.2)
# Out:
# Epoch 1/300
# 14/14 [==============================] - 1s 27ms/step - loss: 11.9851 - val_loss: 13.1739
# Epoch 2/300
# 14/14 [==============================] - 0s 6ms/step - loss: 11.6920 - val_loss: 12.7706
# Epoch 3/300
# 14/14 [==============================] - 0s 6ms/step - loss: 11.3970 - val_loss: 12.3594
# Epoch 4/300
# 14/14 [==============================] - 0s 5ms/step - loss: 11.0814 - val_loss: 11.9155
# Epoch 5/300
# 14/14 [==============================] - 0s 5ms/step - loss: 10.7378 - val_loss: 11.4257
# Epoch 6/300
# 14/14 [==============================] - 0s 6ms/step - loss: 10.3618 - val_loss: 10.8868
# Epoch 7/300
# 14/14 [==============================] - 0s 6ms/step - loss: 9
300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.4849 - val_loss: 101.6701
# Epoch 91/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.4886 - val_loss: 100.4042
# Epoch 92/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.5042 - val_loss: 101.3280
# Epoch 93/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.5207 - val_loss: 100.2655
# Epoch 94/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.5270 - val_loss: 100.4940
# Epoch 95/300
# 14/14 [==============================] - 0s 8ms/step - loss: -4.5368 - val_loss: 100.7719
# Epoch 96/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.5492 - val_loss: 98.5702
# Epoch 97/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.5510 - val_loss: 102.5446
# Epoch 98/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.5687 - val_loss: 99.9636
# Epoch 99/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.5793 - val_loss: 99.0837
# Epoch 100/300
# 14/14 [==============================] - 0s 8ms/step - loss: -4.5922 - val_loss: 100.1806
# Epoch 101/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.6034 - val_loss: 98.1228
# Epoch 102/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.6113 - val_loss: 100.0683
# Epoch 103/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.6197 - val_loss: 99.3022
# Epoch 104/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.6313 - val_loss: 98.3074
# Epoch 105/300
# 14/14 [==============================] - 0s 7ms/step - loss: -4.6367 - val_loss: 98.6420
# Epoch 106/300
# 14/14 [==============================] - 0s 7ms/step - loss: -4.6489 - val_loss: 99.8165
# Epoch 107/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.6576 - val_loss: 98.8171
# Epoch 108/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.6687 - val_loss: 98.5623
# Epoch 109/300
# 14/14 [==============================] - 0s 8ms/step - loss: -4.6748 - val_loss: 98.4775
# Epoch 110/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.6845 - val_loss: 100.0958
# Epoch 111/300
# 14/14 [==============================] - 0s 7ms/step - loss: -4.6976 - val_loss: 97.4908
# Epoch 112/300
# 14/14 [==============================] - 0s 7ms/step - loss: -4.7006 - val_loss: 99.5271
# Epoch 113/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.7114 - val_loss: 97.2167
# Epoch 114/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.7255 - val_loss: 98.8901
# Epoch 115/300
# 14/14 [==============================] - 0s 7ms/step - loss: -4.7304 - val_loss: 98.3380
# Epoch 116/300
# 14/14 [==============================] - 0s 7ms/step - loss: -4.7412 - val_loss: 98.8774
# Epoch 117/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.7480 - val_loss: 99.6580
# Epoch 118/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.7562 - val_loss: 99.3135
# Epoch 119/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.7632 - val_loss: 98.1051
# Epoch 120/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.7668 - val_loss: 98.6405
# Epoch 121/300
# 14/14 [==============================] - 0s 8ms/step - loss: -4.7826 - val_loss: 99.3880
# Epoch 122/300
# 14/14 [==============================] - 0s 7ms/step - loss: -4.7944 - val_loss: 98.9644
# Epoch 123/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.8026 - val_loss: 99.4941
# Epoch 124/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.8107 - val_loss: 101.4568
# Epoch 125/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.8196 - val_loss: 99.1954
# Epoch 126/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.8272 - val_loss: 98.4310
# Epoch 127/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.8339 - val_loss: 100.1838
# Epoch 128/300
# 14/14 [==============================] - 0s 5ms/step - loss: -4.8442 - val_loss: 100.0549
# Epoch 129/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.8517 - val_loss: 99.3537
# Epoch 130/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.8607 - val_loss: 99.8412
# Epoch 131/300
# 14/14 [==============================] - 0s 7ms/step - loss: -4.8577 - val_loss: 99.7645
# Epoch 132/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.8771 - val_loss: 98.9913
# Epoch 133/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.8862 - val_loss: 100.9887
# Epoch 134/300
# 14/14 [==============================] - 0s 8ms/step - loss: -4.8934 - val_loss: 100.5601
# Epoch 135/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.8992 - val_loss: 101.4046
# Epoch 136/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.9041 - val_loss: 101.5571
# Epoch 137/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.9155 - val_loss: 100.6909
# Epoch 138/300
# 14/14 [==============================] - 0s 7ms/step - loss: -4.9211 - val_loss: 102.3643
# Epoch 139/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.9249 - val_loss: 103.2408
# Epoch 140/300
# 14/14 [==============================] - 0s 10ms/step - loss: -4.9269 - val_loss: 101.4125
# Epoch 141/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4.9446 - val_loss: 104.8056
# Epoch 142/300
# 14/14 [==============================] - 0s 6ms/step - loss: -4
300
# 14/14 [==============================] - 0s 6ms/step - loss: -5.6336 - val_loss: 241.3247
# Epoch 262/300
# 14/14 [==============================] - 0s 7ms/step - loss: -5.6338 - val_loss: 255.3173
# Epoch 263/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.6403 - val_loss: 250.7427
# Epoch 264/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.6429 - val_loss: 254.7334
# Epoch 265/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.6499 - val_loss: 254.3756
# Epoch 266/300
# 14/14 [==============================] - 0s 6ms/step - loss: -5.6515 - val_loss: 267.7419
# Epoch 267/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.6613 - val_loss: 265.3225
# Epoch 268/300
# 14/14 [==============================] - 0s 7ms/step - loss: -5.6661 - val_loss: 264.7854
# Epoch 269/300
# 14/14 [==============================] - 0s 7ms/step - loss: -5.6673 - val_loss: 276.1120
# Epoch 270/300
# 14/14 [==============================] - 0s 6ms/step - loss: -5.6725 - val_loss: 282.0140
# Epoch 271/300
# 14/14 [==============================] - 0s 7ms/step - loss: -5.6797 - val_loss: 281.0857
# Epoch 272/300
# 14/14 [==============================] - 0s 7ms/step - loss: -5.6821 - val_loss: 280.7358
# Epoch 273/300
# 14/14 [==============================] - 0s 8ms/step - loss: -5.6785 - val_loss: 288.0809
# Epoch 274/300
# 14/14 [==============================] - 0s 6ms/step - loss: -5.6977 - val_loss: 293.4460
# Epoch 275/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.6992 - val_loss: 290.2096
# Epoch 276/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.6977 - val_loss: 296.2271
# Epoch 277/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7052 - val_loss: 308.7225
# Epoch 278/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7006 - val_loss: 306.1813
# Epoch 279/300
# 14/14 [==============================] - 0s 6ms/step - loss: -5.7105 - val_loss: 315.4622
# Epoch 280/300
# 14/14 [==============================] - 0s 6ms/step - loss: -5.7135 - val_loss: 309.0540
# Epoch 281/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7253 - val_loss: 323.5668
# Epoch 282/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7305 - val_loss: 325.9441
# Epoch 283/300
# 14/14 [==============================] - 0s 4ms/step - loss: -5.7338 - val_loss: 329.2944
# Epoch 284/300
# 14/14 [==============================] - 0s 4ms/step - loss: -5.7400 - val_loss: 335.7653
# Epoch 285/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7444 - val_loss: 348.5156
# Epoch 286/300
# 14/14 [==============================] - 0s 4ms/step - loss: -5.7427 - val_loss: 343.4872
# Epoch 287/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7414 - val_loss: 349.6730
# Epoch 288/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7564 - val_loss: 352.9084
# Epoch 289/300
# 14/14 [==============================] - 0s 4ms/step - loss: -5.7616 - val_loss: 361.4650
# Epoch 290/300
# 14/14 [==============================] - 0s 4ms/step - loss: -5.7645 - val_loss: 364.2363
# Epoch 291/300
# 14/14 [==============================] - 0s 4ms/step - loss: -5.7667 - val_loss: 374.4025
# Epoch 292/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7709 - val_loss: 375.8872
# Epoch 293/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7824 - val_loss: 383.4296
# Epoch 294/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7823 - val_loss: 378.3129
# Epoch 295/300
# 14/14 [==============================] - 0s 7ms/step - loss: -5.7867 - val_loss: 393.3354
# Epoch 296/300
# 14/14 [==============================] - 0s 7ms/step - loss: -5.7809 - val_loss: 397.5092
# Epoch 297/300
# 14/14 [==============================] - 0s 6ms/step - loss: -5.7974 - val_loss: 410.8455
# Epoch 298/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.7956 - val_loss: 410.7020
# Epoch 299/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.8052 - val_loss: 429.3426
# Epoch 300/300
# 14/14 [==============================] - 0s 5ms/step - loss: -5.8024 - val_loss: 427.2183

# %%
plt.figure(figsize=(10, 5))
#plt.ylim([0,9])
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.show()

# %%
y_test = model.predict(Y12)
y_test
# Out:
# 69/69 [==============================] - 0s 2ms/step
# array([[-0.13845718, -0.08184549, -0.10161692, ...,  0.04408747,
#          0.04954612,  0.13848963],
#        [ 0.01524371,  0.04999921,  0.03258404, ...,  0.05991173,
#          0.06629801,  0.09237444],
#        [-0.03659576,  0.00553125, -0.01267862, ...,  0.05402416,
#          0.06009501,  0.10792794],
#        ...,
#        [-0.70867956, -0.5051044 , -0.6021886 , ...,  0.01243746,
#          0.0139755 ,  0.20167771],
#        [-0.7352104 , -0.5227351 , -0.62556314, ...,  0.01167959,
#          0.01310021,  0.20123972],
#        [-0.9308841 , -0.65276635, -0.79795766, ...,  0.0073458 ,
#          0.00813037,  0.19800955]], dtype=float32)
