# %%
import pandas as pd

# %%
# Bases de datos
mass = pd.read_csv("Mass.csv")
mass[['1','0','1n']]
mass
# Out:
#         1     0     1n Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0       1    10     1H        NaN        NaN        NaN        NaN
# 1       2    10     2H        NaN        NaN        NaN        NaN
# 2       3    10     3H        NaN        NaN        NaN        NaN
# 3       3    20    3He        NaN        NaN        NaN        NaN
# 4       3    30    3Li        NaN        NaN        NaN        NaN
# ...   ...   ...    ...        ...        ...        ...        ...
# 5837  293  1170  293Ts        NaN    194430#        NaN        NaN
# 5838  293  1180  293Og        NaN    198800#        NaN        NaN
# 5839  294  1170  294Ts        NaN    196400#        NaN        NaN
# 5840  294  1180  294Og        NaN    199320#        NaN        NaN
# 5841  295  1180  295Og        NaN    201370#        NaN        NaN
#
#        Unnamed: 7    Unnamed: 8    8071.3181  ... Unnamed: 88 Unnamed: 89  \
# 0             NaN           NaN  7288.971064  ...         NaN         NaN
# ...

# %%
matrix = []
lista = []

for i in range(0, 5842):
    for j in mass.columns:
        
        # Se carga la entrada en una variable
        entry = mass.loc[i,j]
        
        # Se almacenan los datos diferentes de NaN
        if (not mass.iloc[[i]][j].isna().bool()):
            lista.append(entry)
            
        # Solo interesan los primeros datos
        if len(lista) == 5:
            break
                
    # Se almacenan los datos en una matriz
    matrix.append(lista)
    lista = []
    
for i in range(len(matrix)):

    # Se divide la entrada por 10
    matrix[i][1] = int(matrix[i][1]/10)
    
    # Se extraen los datos de interés
    if (matrix[i][3] == 'i' or matrix[i][3] == 'j' or matrix[i][3] == 'm' or matrix[i][3] == 'p' or matrix[i][3] == 'n' or matrix[i][3] == 'q' or matrix[i][3] == 'r' or matrix[i][3] == 'x'):
        matrix[i] = [matrix[i][0], matrix[i][1], matrix[i][2], matrix[i][4]]
    else:
        matrix[i] = [matrix[i][0], matrix[i][1], matrix[i][2], matrix[i][3]]
matrix
# Out:
# [[1, 1, '1H', '7288.971064'],
#  [2, 1, '2H', '13135.722895'],
#  [3, 1, '3H', '14949.8109'],
#  [3, 2, '3He', '14931.21888'],
#  [3, 3, '3Li', '28670#'],
#  [4, 1, '4H', '24620'],
#  [4, 2, '4He', '2424.91587'],
#  [4, 3, '4Li', '25320'],
#  [5, 1, '5H', '32890'],
#  [5, 2, '5He', '11231'],
#  [5, 3, '5Li', '11680'],
#  [5, 4, '5Be', '37140#'],
#  [6, 1, '6H', '41880'],
#  [6, 2, '6He', '17592.1'],
#  [6, 3, '6Li', '14086.8804'],
#  [6, 3, '6Li', '17649.76'],
#  [6, 4, '6Be', '18375'],
#  [6, 5, '6B', '47320#'],
#  [7, 1, '7H', '49140#'],
#  [7, 2, '7He', '26073'],
#  [7, 3, '7Li', '14907.105'],
#  [7, 3, '7Li', '26150'],
#  [7, 4, '7Be', '15769'],
#  [7, 4, '7Be', '26750'],
#  [7, 5, '7B', '27677'],
#  [8, 2, '8He', '31609.68'],
#  [8, 3, '8Li', '20945.8'],
#  [8, 3, '8Li', '31768'],
#  [8, 4, '8Be', '4941.67'],
#  [8, 4, '8Be', '21568'],
#  [8, 4, '8Be', '32436'],
#  [8, 5, '8B', '22921.6'],
#  [8, 5, '8B', '33546'],
#  [8, 6, '8C', '35064'],
#  [9, 2, '9He', '40940'],
# ...

# %%
import pandas as pd

# Bases de datos
mass = pd.read_csv("NUBASE1.csv")
mass.columns = ['AAA','ZZZi','AEl', 's', 'Mass#', 'dMass#']
mass['Mass#'] = mass['Mass#'].str.replace('#', '.0')
mass['dMass#'] = mass['dMass#'].str.replace('#', '.0')
mass['ZZZi'] = mass['ZZZi']/10

mass
# Out:
#       AAA   ZZZi    AEl    s         Mass#  dMass#
# 0       1    1.0     1H  NaN   7288.971064   1E-05
# 1       2    1.0     2H  NaN  13135.722895   1E-05
# 2       3    1.0     3H  NaN    14949.8109   8E-05
# 3       3    2.0    3He  NaN   14931.21888   6E-05
# 4       3    3.0    3Li  NaN       28670.0  2000.0
# ...   ...    ...    ...  ...           ...     ...
# 5837  293  117.0  293Ts  NaN      194430.0   780.0
# 5838  293  118.0  293Og  NaN      198800.0   710.0
# 5839  294  117.0  294Ts  NaN      196400.0   590.0
# 5840  294  118.0  294Og  NaN      199320.0   550.0
# 5841  295  118.0  295Og  NaN      201370.0   660.0
#
# [5842 rows x 6 columns]
